# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("1.csv")
data
# Out:
#       Dataset   A    B    C   D
# 0     January  90  100   10   5
# 1    February  80   95   20  10
# 2       March  70   90   30  15
# 3       April  60   85   40  20
# 4         May  50   80   50  25
# 5        June  40   75   60  30
# 6        July  30   70   70  35
# 7      August  20   65   80  40
# 8   September  10   60   90  45
# 9     October   0   55  100  50
# 10   November  10   60   90  45
# 11   December  20   65   80  40
# 12     Monday  30   70   70  35
# 13    Tuesday  40   75   60  30
# 14  Wednesday  50   80   50  25
# 15   Thursday  60   85   40  20
# 16     Friday  70   90   30  15
# 17   Saturday  80   95   20  10
# 18     Sunday  90  100   10   5

# %%
graph_name="1.pdf"
my_xticks=data["Dataset"]

plt.figure(figsize=(10,10))
plt.plot(my_xticks,data["A"], linestyle='-', marker='o', color='b',label= "A")
plt.plot(my_xticks,data["B"], linestyle='-', marker='o', color='r',label= "B")
plt.plot(my_xticks,data["C"], linestyle='-', marker='o', color='k',label= "C")
plt.plot(my_xticks,data["D"], linestyle='-', marker='o', color='g',label= "D")
plt.title("ML Scores ")
plt.legend(numpoints=1)
plt.ylabel("F1 Score")
plt.xticks(rotation=90) 
plt.ylim([-10, 110]) 
plt.savefig(graph_name,bbox_inches='tight',format="pdf")#, dpi=400)

# %%
sns.set_style("whitegrid")



graph_name="1.pdf"
my_xticks=data["Dataset"]

plt.figure(figsize=(10,10))
plt.plot(my_xticks,data["A"], linestyle='-', marker='o', color='b',label= "A")
plt.plot(my_xticks,data["B"], linestyle='-', marker='o', color='r',label= "B")
plt.plot(my_xticks,data["C"], linestyle='-', marker='o', color='k',label= "C")
plt.plot(my_xticks,data["D"], linestyle='-', marker='o', color='g',label= "D")
plt.title("ML Scores ")
plt.legend(numpoints=1)
plt.ylabel("F1 Score")
plt.xticks(rotation=90) 
plt.ylim([-10, 110]) 
plt.savefig(graph_name,bbox_inches='tight',format="pdf")#, dpi=400)

# %%
styles=["darkgrid", "whitegrid", "dark", "white", "ticks"]




for style in styles:
    sns.set_style(style)
    graph_name="1.pdf"
    my_xticks=data["Dataset"]

    plt.figure(figsize=(10,10))
    plt.plot(my_xticks,data["A"], linestyle='-', marker='o', color='b',label= "A")
    plt.plot(my_xticks,data["B"], linestyle='-', marker='o', color='r',label= "B")
    plt.plot(my_xticks,data["C"], linestyle='-', marker='o', color='k',label= "C")
    plt.plot(my_xticks,data["D"], linestyle='-', marker='o', color='g',label= "D")
    plt.title("ML Scores ")
    plt.legend(numpoints=1)
    plt.ylabel("F1 Score")
    plt.xticks(rotation=90) 
    plt.ylim([-10, 110]) 
    plt.savefig(graph_name,bbox_inches='tight',format="pdf")#, dpi=400)
